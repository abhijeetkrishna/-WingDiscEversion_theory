# %% [markdown]
# To do
# - ---Select a genotype
# - ---Select a crosssection
# - ---take curves for that crosssection
# - ---Compute their curvatures
# - ---Plot them
# - Save curves and plots
# - ---Update name of stages
# - Loop over genotype and crosssection
# - Different color for different stages
#
# - overlay simulation
# - set correct limits

# %%
from wd_2D_functions import *

plot_folder = 'plots/'
os.makedirs(plot_folder,exist_ok=True)

# %%
genotypes = ["ecadGFPnbG4", 
             #"ecadGFPnbG4myoVI"
            ]
crosssections = ["Across_DV","Along_DV", ]

devstage_name_update_dict = {
    "120hAEL":"120hAEL",
    "96hAEL":"96hAEL",
    "upcrawling":"wL3",
    "whitePupa" : "0hAPF",
    "2hAPF": "2hAPF",
    "4hAPF": "4hAPF",
    "6hAPF": "6hAPF",
}

devstages = ['wL3', '0hAPF', '2hAPF', '4hAPF','6hAPF']

#fig, axs = plt.subplots(2, len(devstages), figsize=(7*len(devstages), 15))

for genotype in genotypes:
    fig, axs = plt.subplots(2, len(devstages), figsize=(7*len(devstages), 15))
    
    for crosssection in crosssections:
        
        file = '../exp_data/segmented_curves/' + crosssection + "_" + genotype + "_pouchShape.pkl"
        
        #files = ['../exp_data/segmented_curves/along_DV_pouchShape_ecadGFPnbG4.pkl'] #Along DV
        #files = ['../exp_data/segmented_curves/ecadGFPnbG4pouchShape.pkl'] #Across DV
        #files = ['shapes.csv']

        
        #devstages = ['upcrawling', 'whitePupa', '2hAPF', '4hAPF','6hAPF']
        allcurves = import_raw_crosssection_points(files = [file], plot = False,)
        #allcurves = allcurves[allcurves["genotype"] == genotype]


        #updating name of devstages


        allcurves["devstage"] = allcurves.apply(lambda row: devstage_name_update_dict[row["devstage"]], axis = 1) #[devstage_name_update[x] for x in allcurves["devstage"].values]
        



        #fig, axs = plt.subplots(2, len(devstages), figsize=(7*len(devstages), 15))


        # align
        allcurves = align_curves(allcurves = allcurves,orientation = 'horizontal', devstages=devstages, filename  = plot_folder + genotype + "_" + crosssection + '_aligned.pdf'
                                )
        
        #interpolate
        [df_all, df_mean] = interpolate_average_curves(allcurves, devstages=devstages,)
        
        df_all["crosssection"] = crosssection
        df_mean["crosssection"] = crosssection


        #save csv
        df_all.to_csv(file.replace(".pkl", "_interpolated_all.csv"), index = False)
        df_mean.to_csv(file.replace(".pkl", "_interpolated_mean.csv"), index = False)

        #plotting
        scalebar_stage = "wL3"
        scalebar_x_pos = 120
        scalebar_y_pos = -450
        scalebar_size = 100
        scalebar_linewidth = 5
        scalebar_fontsize = 20
        scalebar_color = 'black'

        for j in range(len(devstages)):

            devstage = devstages[j]

            df = df_mean[((df_mean['genotype'] == genotype) & (df_mean['devstage'] == devstage)) & (df_mean['crosssection'] == crosssection)]
            #gen_dev = database[(database['genotype'] == genotype) & (database['devstage'] == devstage)]

            #plot mean curve

            #linestyle
            if crosssection == "Across_DV":
                linestyle = "-"
            else:
                linestyle = "--"


            ax = axs[0, j] #axs[j, 0]
            #ax.axis('equal')
            ax.set_ylim(-510, 10)
            ax.set_xlim(-260, 260)
            ax.plot(df['x'], df['y'],color = 'red',linewidth = 4, label = 'Mean', zorder = 2, linestyle = linestyle)
            ax.errorbar(df['x'], df['y'], xerr = df['x_sd'], yerr = df['y_sd'],ecolor = 'gray', alpha = 0.5, label = 'Std dev', zorder = 1)
            #ax.fill_between(df['x'], df['curvature'] - df['curvature_sd'], df['curvature'] + df['curvature_sd'], color = 'gray', alpha = 0.2)

            #ax.set_ylabel(devstage, fontsize = 30, rotation = 0, labelpad = 100)


            #adding scale bar
            ax.plot([scalebar_x_pos, scalebar_x_pos + scalebar_size],[scalebar_y_pos,scalebar_y_pos], lw = scalebar_linewidth, color = scalebar_color)
            if devstage == scalebar_stage:
                ax.text(x = scalebar_x_pos + 10, y = scalebar_y_pos + 20, s = str(scalebar_size) + ' ' + r'$\mu m$', fontsize = scalebar_fontsize)


            #switching off ticks
            ax.set_xticklabels([])
            ax.set_yticklabels([])
            ax.set_xticks([])
            ax.set_yticks([])
            #ax.tick_params(axis='both', which='both', bottom='off', top='off', labelbottom='off', right='off', left='off', labelleft='off')

            #if j == 0:
            ax.set_title(devstage, fontsize = 30,)


            #plot mean curvature
            ax = axs[1, j]
            ax.set_ylim(-0.022, 0.022)
            ax.set_xlim(-300, 300)
            #ax.plot(df['arclength'],df['curvature'], color = 'black', alpha = 1,)
            ax.set_xlabel('Arclength ' + r'$(\mu m)$', fontsize = 20)
            #ax.set_ylabel('Curvature ' + r'$(\mu m^{-1})$', fontsize = 20, labelpad = 10)
            #ax.fill_between(df['arclength'], df['curvature'] - df['curvature_sd'], df['curvature'] + df['curvature_sd'], color = 'gray', alpha = 0.2)
            ax.fill_between(x = df['arclength'].tolist(), y1 = (df['curvature'] - df['curvature_sd']).tolist(), y2 = (df['curvature'] + df['curvature_sd']).tolist(), color = 'gray', alpha = 0.2)
            ax.plot(df['arclength'], df['curvature'], label = crosssection, linewidth = 4, color = 'red', linestyle = linestyle,
                   )


            #if j == 0:
            ax.set_title('Curvature ' + r'$(\mu m^{-1})$', fontsize = 30)
            ax.set_xticks([-150, 0, 150])
            if devstage == '6hAPF':
                #if max(df['curvature']) > 0.02:
                #ax.set_ylim(-1.1*max(df['curvature'] + df['curvature_sd']),1.1*max(df['curvature'] + df['curvature_sd']))
                ax.set_ylim(-0.08, 0.08)
                ax.set_yticks([-0.03, 0, 0.03])
            else:
                ax.set_yticks([-0.02, -0.01, 0, 0.01, 0.02])
            #ax.tick_params(axis = 'both', which = 'both', fontsize = 20)
            ax.tick_params(axis = 'both', labelsize = 20)
            ax.grid()
            
            ax.legend(fontsize = 30)
# Out:
# file : ../exp_data/segmented_curves/Across_DV_ecadGFPnbG4_pouchShape.pkl
# crosssection is Across DV
# file : ../exp_data/segmented_curves/Along_DV_ecadGFPnbG4_pouchShape.pkl
# crosssection is Along DV

# %% [markdown]
# ### With Model

# %%
genotypes = ["ecadGFPnbG4", 
             #"ecadGFPnbG4myoVI"
            ]
crosssections = [#"Across_DV",
                 "Along_DV", 
                ]

devstage_name_update_dict = {
    "120hAEL":"120hAEL",
    "96hAEL":"96hAEL",
    "upcrawling":"wL3",
    "whitePupa" : "0hAPF",
    "2hAPF": "2hAPF",
    "4hAPF": "4hAPF",
    "6hAPF": "6hAPF",
}

devstages = ['wL3', '0hAPF', '2hAPF', '4hAPF',]

#fig, axs = plt.subplots(2, len(devstages), figsize=(7*len(devstages), 15))

for genotype in genotypes:
    fig, axs = plt.subplots(2, len(devstages), figsize=(7*len(devstages), 15))
    
    for crosssection in crosssections:
        
        file = '../exp_data/segmented_curves/' + crosssection + "_" + genotype + "_pouchShape.pkl"
        
        #files = ['../exp_data/segmented_curves/along_DV_pouchShape_ecadGFPnbG4.pkl'] #Along DV
        #files = ['../exp_data/segmented_curves/ecadGFPnbG4pouchShape.pkl'] #Across DV
        #files = ['shapes.csv']

        
        #devstages = ['upcrawling', 'whitePupa', '2hAPF', '4hAPF','6hAPF']
        allcurves = import_raw_crosssection_points(files = [file], plot = False,)
        #allcurves = allcurves[allcurves["genotype"] == genotype]


        #updating name of devstages


        allcurves["devstage"] = allcurves.apply(lambda row: devstage_name_update_dict[row["devstage"]], axis = 1) #[devstage_name_update[x] for x in allcurves["devstage"].values]
        
        #fig, axs = plt.subplots(2, len(devstages), figsize=(7*len(devstages), 15))


        # align
        allcurves = align_curves(allcurves = allcurves,orientation = 'horizontal', devstages=devstages, filename  = plot_folder + genotype + "_" + crosssection + '_aligned.pdf'
                                )
        
        #interpolate
        [df_all, df_mean] = interpolate_average_curves(allcurves, devstages=devstages,)
        
        df_all["crosssection"] = crosssection
        df_mean["crosssection"] = crosssection


        #save csv
        df_all.to_csv(file.replace(".pkl", "_interpolated_all.csv"), index = False)
        df_mean.to_csv(file.replace(".pkl", "_interpolated_mean.csv"), index = False)

        #plotting
        scalebar_stage = "wL3"
        scalebar_x_pos = 120
        scalebar_y_pos = -450
        scalebar_size = 100
        scalebar_linewidth = 5
        scalebar_fontsize = 20
        scalebar_color = 'black'

        for j in range(len(devstages)):

            devstage = devstages[j]

            df = df_mean[((df_mean['genotype'] == genotype) & (df_mean['devstage'] == devstage)) & (df_mean['crosssection'] == crosssection)]
            df = df[(-100 < df["arclength"]) &(df["arclength"] < 100) ]
            #gen_dev = database[(database['genotype'] == genotype) & (database['devstage'] == devstage)]

            #plot mean curve

            #linestyle
            if crosssection == "Across_DV":
                linestyle = "-"
            else:
                linestyle = "--"


            ax = axs[0, j] #axs[j, 0]
            ax.axis('equal')
            ax.set_ylim(-80, 10)
            ax.set_xlim(-110, 110)
            ax.plot(df['x'], df['y'],color = 'red',linewidth = 4, label = 'Mean', zorder = 2, linestyle = linestyle)
            ax.errorbar(df['x'], df['y'], xerr = df['x_sd'], yerr = df['y_sd'],ecolor = 'gray', alpha = 0.5, label = 'Std dev', zorder = 1)
            #ax.fill_between(df['x'], df['curvature'] - df['curvature_sd'], df['curvature'] + df['curvature_sd'], color = 'gray', alpha = 0.2)

            #ax.set_ylabel(devstage, fontsize = 30, rotation = 0, labelpad = 100)


            #adding scale bar
            ax.plot([scalebar_x_pos, scalebar_x_pos + scalebar_size],[scalebar_y_pos,scalebar_y_pos], lw = scalebar_linewidth, color = scalebar_color)
            if devstage == scalebar_stage:
                ax.text(x = scalebar_x_pos + 10, y = scalebar_y_pos + 20, s = str(scalebar_size) + ' ' + r'$\mu m$', fontsize = scalebar_fontsize)


            #switching off ticks
            ax.set_xticklabels([])
            ax.set_yticklabels([])
            ax.set_xticks([])
            ax.set_yticks([])
            #ax.tick_params(axis='both', which='both', bottom='off', top='off', labelbottom='off', right='off', left='off', labelleft='off')

            #if j == 0:
            ax.set_title(devstage, fontsize = 30,)
            
            #Plotting simulation
            sim_dir = "../simulation/sample_data/data_version_latest/WT_StageWise_w_uniform_thickness_till_4hAPF/wd_thickness_0.1_nb_iterations_10/sim_output/"
            sim_df = pd.read_csv(sim_dir + devstage + "_" + crosssection + "_curve.csv")
            ax.plot(sim_df['x'], sim_df['y'],color = 'black',linewidth = 4, label = 'Model ' + crosssection, zorder = 2, linestyle = linestyle)

            #plot mean curvature
            ax = axs[1, j]
            ax.set_ylim(-0.022, 0.022)
            ax.set_xlim(-140, 140)
            #ax.plot(df['arclength'],df['curvature'], color = 'black', alpha = 1,)
            ax.set_xlabel('Arclength ' + r'$(\mu m)$', fontsize = 20)
            #ax.set_ylabel('Curvature ' + r'$(\mu m^{-1})$', fontsize = 20, labelpad = 10)
            #ax.fill_between(df['arclength'], df['curvature'] - df['curvature_sd'], df['curvature'] + df['curvature_sd'], color = 'gray', alpha = 0.2)
            ax.fill_between(x = df['arclength'].tolist(), y1 = (df['curvature'] - df['curvature_sd']).tolist(), y2 = (df['curvature'] + df['curvature_sd']).tolist(), color = 'gray', alpha = 0.2)
            ax.plot(df['arclength'], df['curvature'], label = crosssection, linewidth = 4, color = 'red', linestyle = linestyle,
                   )
            ax.plot(sim_df['arclength'], sim_df['curvature'], label = "Model " + crosssection, linewidth = 4, color = 'black', linestyle = linestyle,
            )


            #if j == 0:
            ax.set_title('Curvature ' + r'$(\mu m^{-1})$', fontsize = 30)
            ax.set_xticks([-100, 0, 100])
            if devstage == '6hAPF':
                #if max(df['curvature']) > 0.02:
                #ax.set_ylim(-1.1*max(df['curvature'] + df['curvature_sd']),1.1*max(df['curvature'] + df['curvature_sd']))
                ax.set_ylim(-0.07, 0.08)
                ax.set_yticks([-0.03, 0, 0.03])
            else:
                ax.set_yticks([0, 0.01, 0.02, 0.03, 0.04])
            #ax.tick_params(axis = 'both', which = 'both', fontsize = 20)
            ax.tick_params(axis = 'both', labelsize = 20)
            ax.grid()
            
            ax.legend(fontsize = 15)
# Out:
# file : ../exp_data/segmented_curves/Along_DV_ecadGFPnbG4_pouchShape.pkl
# crosssection is Along DV

# %%
df[(-100 < df["arclength"]) &(df["arclength"] < 100) ]
# Out:
#        genotype devstage  arclength          x          y      x_sd      y_sd  \
# 31  ecadGFPnbG4      wL3 -98.540288  92.989708 -20.889301  2.524606  9.643020
# 32  ecadGFPnbG4      wL3 -93.183811  88.513978 -17.979364  2.210834  9.167669
# 33  ecadGFPnbG4      wL3 -87.827334  83.920407 -15.277250  1.905794  8.668010
# 34  ecadGFPnbG4      wL3 -82.470858  79.221011 -12.788017  1.614373  8.150601
# 35  ecadGFPnbG4      wL3 -77.114381  74.427208 -10.515302  1.341063  7.621810
# 36  ecadGFPnbG4      wL3 -71.757904  69.549688  -8.461124  1.089708  7.087463
# 37  ecadGFPnbG4      wL3 -66.401427  64.598327  -6.625687  0.863321  6.552503
# 38  ecadGFPnbG4      wL3 -61.044951  59.582208  -5.007186  0.664053  6.020677
# 39  ecadGFPnbG4      wL3 -55.688474  54.509693  -3.601752  0.493298  5.494367
# 40  ecadGFPnbG4      wL3 -50.331997  49.388488  -2.403660  0.351980  4.974732
# 41  ecadGFPnbG4      wL3 -44.975520  44.225683  -1.405657  0.241130  4.461962
# 42  ecadGFPnbG4      wL3 -39.619044  39.027803  -0.599287  0.162850  3.955501
# 43  ecadGFPnbG4      wL3 -34.262567  33.800844   0.024783  0.120046  3.454264
# 44  ecadGFPnbG4      wL3 -28.906090  28.550326   0.476429  0.108517  2.956846
# 45  ecadGFPnbG4      wL3 -23.549613  23.281332   0.765748  0.111396  2.461754
# 46  ecadGFPnbG4      wL3 -18.193137  17.998556   0.902728  0.114231  1.967749
# 47  ecadGFPnbG4      wL3 -12.836660  12.706344   0.896919  0.111683  1.474508
# 48  ecadGFPnbG4      wL3  -7.480183   7.408744   0.757108  0.103408  0.984734
# 49  ecadGFPnbG4      wL3  -2.123706   2.109546   0.490989  0.091210  0.516929
# 50  ecadGFPnbG4      wL3   3.232770  -3.187673   0.104836  0.078357  0.278701
# 51  ecadGFPnbG4      wL3   8.589247  -8.479499  -0.396782  0.070199  0.639891
# 52  ecadGFPnbG4      wL3  13.945724 -13.762612  -1.011063  0.073804  1.123537
# 53  ecadGFPnbG4      wL3  19.302201 -19.033710  -1.736834  0.092609  1.619182
# 54  ecadGFPnbG4      wL3  24.658677 -24.289417  -2.574401  0.124409  2.110537
# 55  ecadGFPnbG4      wL3  30.015154 -29.526202  -3.525395  0.166585  2.589445
# 56  ecadGFPnbG4      wL3  35.371631 -34.740292  -4.592616  0.218027  3.049081
# 57  ecadGFPnbG4      wL3  40.728108 -39.927591  -5.779881  0.278418  3.482930
# 58  ecadGFPnbG4      wL3  46.084584 -45.083590  -7.091872  0.347530  3.884688
# 59  ecadGFPnbG4      wL3  51.441061 -50.203287  -8.533981  0.424830  4.248386
# 60  ecadGFPnbG4      wL3  56.797538 -55.281097 -10.112154  0.509251  4.568591
# 61  ecadGFPnbG4      wL3  62.154015 -60.310774 -11.832741  0.599047  4.840629
# 62  ecadGFPnbG4      wL3  67.510491 -65.285321 -13.702340  0.691696  5.060809
# 63  ecadGFPnbG4      wL3  72.866968 -70.196907 -15.727647  0.783839  5.226630
# 64  ecadGFPnbG4      wL3  78.223445 -75.036819 -17.915312  0.871319  5.336901
# 65  ecadGFPnbG4      wL3  83.579922 -79.795470 -20.271818  0.949375  5.391695
# 66  ecadGFPnbG4      wL3  88.936398 -84.462455 -22.803309  1.012929  5.392265
# 67  ecadGFPnbG4      wL3  94.292875 -89.026568 -25.515390  1.057032  5.340930
# 68  ecadGFPnbG4      wL3  99.649352 -93.475792 -28.412907  1.077563  5.240937
#
#     curvature  curvature_sd crosssection
# 31   0.008355      0.000981    Across_DV
# 32   0.008324      0.000777    Across_DV
# 33   0.008308      0.000683    Across_DV
# 34   0.008292      0.000722    Across_DV
# 35   0.008261      0.000840    Across_DV
# 36   0.008199      0.000968    Across_DV
# 37   0.008086      0.001062    Across_DV
# 38   0.007908      0.001091    Across_DV
# 39   0.007665      0.001055    Across_DV
# 40   0.007365      0.000963    Across_DV
# 41   0.007018      0.000834    Across_DV
# 42   0.006639      0.000693    Across_DV
# 43   0.006242      0.000571    Across_DV
# 44   0.005840      0.000502    Across_DV
# 45   0.005448      0.000506    Across_DV
# 46   0.005079      0.000562    Across_DV
# 47   0.004744      0.000632    Across_DV
# 48   0.004455      0.000686    Across_DV
# 49   0.004223      0.000710    Across_DV
# 50   0.004059      0.000696    Across_DV
# 51   0.003964      0.000654    Across_DV
# 52   0.003933      0.000611    Across_DV
# 53   0.003961      0.000600    Across_DV
# 54   0.004041      0.000655    Across_DV
# 55   0.004169      0.000778    Across_DV
# 56   0.004339      0.000950    Across_DV
# 57   0.004546      0.001145    Across_DV
# 58   0.004784      0.001344    Across_DV
# 59   0.005048      0.001532    Across_DV
# 60   0.005334      0.001696    Across_DV
# 61   0.005636      0.001828    Across_DV
# 62   0.005954      0.001923    Across_DV
# 63   0.006285      0.001984    Across_DV
# 64   0.006629      0.002019    Across_DV
# 65   0.006981      0.002038    Across_DV
# 66   0.007340      0.002050    Across_DV
# 67   0.007700      0.002065    Across_DV
# 68   0.008058      0.002088    Across_DV

# %%
crosssection = "Along_DV"
file = '../exp_data/segmented_curves/' + crosssection + "_" + genotype + "_pouchShape.pkl"

# %%
allcurves_old = allcurves.copy(deep = True)

# %%
allcurves
# Out:
#           x      y                                   disc devstage  \
# 0     220.0  584.0  20201013_ecadGFPnbG4_upcrawling_disc3      wL3
# 1     214.0  574.0  20201013_ecadGFPnbG4_upcrawling_disc3      wL3
# 2     201.0  568.0  20201013_ecadGFPnbG4_upcrawling_disc3      wL3
# 3     187.0  562.0  20201013_ecadGFPnbG4_upcrawling_disc3      wL3
# 4     172.0  553.0  20201013_ecadGFPnbG4_upcrawling_disc3      wL3
# ...     ...    ...                                    ...      ...
# 1738   73.0 -350.0      20210818_ecadGFPnbG4_96hAEL_disc4   96hAEL
# 1739   90.0 -369.0      20210818_ecadGFPnbG4_96hAEL_disc4   96hAEL
# 1740  108.0 -386.0      20210818_ecadGFPnbG4_96hAEL_disc4   96hAEL
# 1741  123.0 -397.0      20210818_ecadGFPnbG4_96hAEL_disc4   96hAEL
# 1742  135.0 -414.0      20210818_ecadGFPnbG4_96hAEL_disc4   96hAEL
#
#          genotype   region   arclength  arclength_offset
# 0     ecadGFPnbG4  ventral    0.000000       -340.026029
# 1     ecadGFPnbG4  ventral   11.661904       -328.364126
# 2     ecadGFPnbG4  ventral   25.979725       -314.046304
# 3     ecadGFPnbG4  ventral   41.211271       -298.814758
# 4     ecadGFPnbG4  ventral   58.704127       -281.321903
# ...           ...      ...         ...               ...
# 1738  ecadGFPnbG4   dorsal  343.112554        128.814810
# 1739  ecadGFPnbG4   dorsal  368.607652        154.309908
# 1740  ecadGFPnbG4   dorsal  393.366488        179.068745
# 1741  ecadGFPnbG4   dorsal  411.967564        197.669820
# 1742  ecadGFPnbG4   dorsal  432.776216        218.478472
#
# [1743 rows x 8 columns]

# %%
allcurves
# Out:
#                x           y                                   disc devstage  \
# 0      97.031567 -189.770585  20201013_ecadGFPnbG4_upcrawling_disc4      wL3
# 1     102.376441 -184.929890  20201013_ecadGFPnbG4_upcrawling_disc4      wL3
# 2     110.541149 -178.657926  20201013_ecadGFPnbG4_upcrawling_disc4      wL3
# 3     115.886022 -173.817231  20201013_ecadGFPnbG4_upcrawling_disc4      wL3
# 4     123.755935 -165.567112  20201013_ecadGFPnbG4_upcrawling_disc4      wL3
# ...          ...         ...                                    ...      ...
# 2214 -119.771379 -164.030688  20210125_ecadGFPnbG4_upcrawling_disc2      wL3
# 2215 -117.417727 -172.717478  20210125_ecadGFPnbG4_upcrawling_disc2      wL3
# 2216 -112.168479 -180.619718  20210125_ecadGFPnbG4_upcrawling_disc2      wL3
# 2217 -109.111145 -188.079792  20210125_ecadGFPnbG4_upcrawling_disc2      wL3
# 2218 -111.402839 -194.917053  20210125_ecadGFPnbG4_upcrawling_disc2      wL3
#
#          genotype   region   arclength  arclength_offset
# 0     ecadGFPnbG4  ventral    0.000000       -307.780852
# 1     ecadGFPnbG4  ventral    7.211103       -300.569750
# 2     ecadGFPnbG4  ventral   17.506733       -290.274120
# 3     ecadGFPnbG4  ventral   24.717835       -283.063017
# 4     ecadGFPnbG4  ventral   36.119589       -271.661263
# ...           ...      ...         ...               ...
# 2214  ecadGFPnbG4   dorsal  531.639110        255.937032
# 2215  ecadGFPnbG4   dorsal  540.639110        264.937032
# 2216  ecadGFPnbG4   dorsal  550.125943        274.423865
# 2217  ecadGFPnbG4   dorsal  558.188201        282.486123
# 2218  ecadGFPnbG4   dorsal  565.399304        289.697225
#
# [2219 rows x 8 columns]

# %%
genotype = "ecadGFPnbG4myoVI"
crosssection = "Across_DV"
file = '../exp_data/segmented_curves/' + crosssection + "_" + genotype + '_pouchShape.pkl'

# %%
allcurves
# Out:
#         x    y                                        disc devstage  \
# 0     680 -323             20200703_nubG4myoVI_2hAPF_disc1    2hAPF
# 1     678 -336             20200703_nubG4myoVI_2hAPF_disc1    2hAPF
# 2     675 -347             20200703_nubG4myoVI_2hAPF_disc1    2hAPF
# 3     672 -357             20200703_nubG4myoVI_2hAPF_disc1    2hAPF
# 4     672 -368             20200703_nubG4myoVI_2hAPF_disc1    2hAPF
# ...   ...  ...                                         ...      ...
# 1991  569 -170  20210125_ecadGFPnbG4myoVI_upcrawling_disc2      wL3
# 1992  573 -181  20210125_ecadGFPnbG4myoVI_upcrawling_disc2      wL3
# 1993  577 -188  20210125_ecadGFPnbG4myoVI_upcrawling_disc2      wL3
# 1994  577 -196  20210125_ecadGFPnbG4myoVI_upcrawling_disc2      wL3
# 1995  575 -204  20210125_ecadGFPnbG4myoVI_upcrawling_disc2      wL3
#
#               genotype   region   arclength  arclength_offset
# 0     ecadGFPnbG4myoVI  ventral    0.000000       -485.649590
# 1     ecadGFPnbG4myoVI  ventral   13.152946       -472.496644
# 2     ecadGFPnbG4myoVI  ventral   24.554701       -461.094890
# 3     ecadGFPnbG4myoVI  ventral   34.995007       -450.654583
# 4     ecadGFPnbG4myoVI  ventral   45.995007       -439.654583
# ...                ...      ...         ...               ...
# 1991  ecadGFPnbG4myoVI   dorsal  554.472894        256.126485
# 1992  ecadGFPnbG4myoVI   dorsal  566.177593        267.831185
# 1993  ecadGFPnbG4myoVI   dorsal  574.239851        275.893443
# 1994  ecadGFPnbG4myoVI   dorsal  582.239851        283.893443
# 1995  ecadGFPnbG4myoVI   dorsal  590.486062        292.139654
#
# [1996 rows x 8 columns]

# %%
crosssection = "Along_DV"
file = '../exp_data/segmented_curves/' + crosssection + "_" + genotype + "_pouchShape.pkl"

# %%
#files = ['../exp_data/segmented_curves/along_DV_pouchShape_ecadGFPnbG4.pkl'] #Along DV
#files = ['../exp_data/segmented_curves/ecadGFPnbG4pouchShape.pkl'] #Across DV
#files = ['shapes.csv']

allcurves = allcurves[allcurves["genotype"] == genotype]
devstages = ['upcrawling', 'whitePupa', '2hAPF', '4hAPF','6hAPF']
allcurves = import_raw_crosssection_points(files = [file], plot = False,)


#updating name of devstages
devstage_name_update_dict = {
    "120hAEL":"120hAEL",
    "96hAEL":"96hAEL",
    "upcrawling":"wL3",
    "whitePupa" : "0hAPF",
    "2hAPF": "2hAPF",
    "4hAPF": "4hAPF",
    "6hAPF": "6hAPF",
}

allcurves["devstage"] = allcurves.apply(lambda row: devstage_name_update_dict[row["devstage"]], axis = 1) #[devstage_name_update[x] for x in allcurves["devstage"].values]
devstages = ['wL3', '0hAPF', '2hAPF', '4hAPF','6hAPF']

fig, axs = plt.subplots(2, len(devstages), figsize=(7*len(devstages), 15))


# align
allcurves = align_curves(allcurves = allcurves,orientation = 'horizontal', devstages=devstages, filename  = plot_folder + genotype + "_" + crosssection + '_aligned.pdf'
                        )

#interpolate
[df_all, df_mean] = interpolate_average_curves(allcurves, devstages=devstages,)
df_all["crosssection"] = crosssection
df_mean["crosssection"] = crosssection


#save csv
df_all.to_csv(file.replace(".pkl", "_interpolated_all.csv"), index = False)
df_mean.to_csv(file.replace(".pkl", "_interpolated_mean.csv"), index = False)

#plotting
scalebar_stage = "wL3"
scalebar_x_pos = 120
scalebar_y_pos = -450
scalebar_size = 100
scalebar_linewidth = 5
scalebar_fontsize = 20
scalebar_color = 'black'

for j in range(len(devstages)):
    
    devstage = devstages[j]
    
    df = df_mean[((df_mean['genotype'] == genotype) & (df_mean['devstage'] == devstage)) & (df_mean['crosssection'] == crosssection)]
    #gen_dev = database[(database['genotype'] == genotype) & (database['devstage'] == devstage)]

    #plot mean curve
    
    #linestyle
    if crosssection == "Across_DV":
        linestyle = "-"
    else:
        linestyle = "--"
    

    ax = axs[0, j] #axs[j, 0]
    #ax.axis('equal')
    ax.set_ylim(-510, 10)
    ax.set_xlim(-260, 260)
    ax.plot(df['x'], df['y'],color = 'red',linewidth = 4, label = 'Mean', zorder = 2, linestyle = linestyle)
    ax.errorbar(df['x'], df['y'], xerr = df['x_sd'], yerr = df['y_sd'],ecolor = 'gray', alpha = 0.5, label = 'Std dev', zorder = 1)
    #ax.fill_between(df['x'], df['curvature'] - df['curvature_sd'], df['curvature'] + df['curvature_sd'], color = 'gray', alpha = 0.2)

    #ax.set_ylabel(devstage, fontsize = 30, rotation = 0, labelpad = 100)


    #adding scale bar
    ax.plot([scalebar_x_pos, scalebar_x_pos + scalebar_size],[scalebar_y_pos,scalebar_y_pos], lw = scalebar_linewidth, color = scalebar_color)
    if devstage == scalebar_stage:
        ax.text(x = scalebar_x_pos + 10, y = scalebar_y_pos + 20, s = str(scalebar_size) + ' ' + r'$\mu m$', fontsize = scalebar_fontsize)


    #switching off ticks
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_xticks([])
    ax.set_yticks([])
    #ax.tick_params(axis='both', which='both', bottom='off', top='off', labelbottom='off', right='off', left='off', labelleft='off')

    #if j == 0:
    ax.set_title(devstage, fontsize = 30,)


    #plot mean curvature
    ax = axs[1, j]
    ax.set_ylim(-0.022, 0.022)
    ax.set_xlim(-300, 300)
    #ax.plot(df['arclength'],df['curvature'], color = 'black', alpha = 1,)
    ax.set_xlabel('Arclength ' + r'$(\mu m)$', fontsize = 20)
    #ax.set_ylabel('Curvature ' + r'$(\mu m^{-1})$', fontsize = 20, labelpad = 10)
    #ax.fill_between(df['arclength'], df['curvature'] - df['curvature_sd'], df['curvature'] + df['curvature_sd'], color = 'gray', alpha = 0.2)
    ax.fill_between(x = df['arclength'].tolist(), y1 = (df['curvature'] - df['curvature_sd']).tolist(), y2 = (df['curvature'] + df['curvature_sd']).tolist(), color = 'gray', alpha = 0.2)
    ax.plot(df['arclength'], df['curvature'], label = genotype, linewidth = 4, color = 'red', linestyle = linestyle )


    #if j == 0:
    ax.set_title('Curvature ' + r'$(\mu m^{-1})$', fontsize = 30)
    ax.set_xticks([-150, 0, 150])
    if devstage == '6hAPF':
        if max(df['curvature']) > 0.02:
            ax.set_ylim(-1.1*max(df['curvature'] + df['curvature_sd']),1.1*max(df['curvature'] + df['curvature_sd']))
            ax.set_yticks([-0.03, 0, 0.03])
    else:
        ax.set_yticks([-0.02, -0.01, 0, 0.01, 0.02])
    #ax.tick_params(axis = 'both', which = 'both', fontsize = 20)
    ax.tick_params(axis = 'both', labelsize = 20)
    ax.grid()
# Out:
# file : ../exp_data/segmented_curves/Across_DV_ecadGFPnbG4myoVI_pouchShape.pkl
# crosssection is Across DV
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/test310/lib/python3.10/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/opt/anaconda3/envs/test310/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/test310/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'arclength'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [44], in <cell line: 32>()
#      28 allcurves = align_curves(allcurves = allcurves,orientation = 'horizontal', devstages=devstages, filename  = plot_folder + genotype + "_" + crosssection + '_aligned.pdf'
#      29                         )
#      31 #interpolate
# ---> 32 [df_all, df_mean] = interpolate_average_curves(allcurves, devstages=devstages,)
#      33 df_all["crosssection"] = crosssection
#      34 df_mean["crosssection"] = crosssection
#
# File ~/PhD/WingDiscEversion_theory/data_analysis/wd_2D_functions.py:488, in interpolate_average_curves(allcurves, genotypes, devstages)
#     486 #get the mean curve
#     487 for arclength in arclengths:
# --> 488     df_arclength = df_all[df_all['arclength'] == arclength]
#     489     #columns = ['genotype', 'devstage', 'arclength','x','y','x_sd','y_sd','curvature','curvature_sd']
#     490     row = pd.DataFrame([[genotype, devstage,arclength,np.mean(df_arclength['x']), np.mean(df_arclength['y']), np.std(df_arclength['x']), np.std(df_arclength['y']), np.mean(df_arclength['curvature']), np.std(df_arclength['curvature'])]], columns=columns)
#
# File ~/opt/anaconda3/envs/test310/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/test310/lib/python3.10/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'arclength'

# %%
plt.show()

# %%
allcurves = align_curves(allcurves = allcurves,orientation = 'horizontal', devstages=devstages, filename  = plot_folder + genotype + "_" + crosssection + '_aligned.pdf'
                        )

# %%
[df_all, df_mean] = interpolate_average_curves(allcurves, devstages=devstages,)
df_all["crosssection"] = crosssection
df_mean["crosssection"] = crosssection

# %%
df_all.to_csv(file.replace(".pkl", "_interpolated_all.csv"), index = False)
df_mean.to_csv(file.replace(".pkl", "_interpolated_mean.csv"), index = False)

# %%
df_all.head()
# Out:
#                                     disc   arclength           x           y  \
# 0  20201013_ecadGFPnbG4_upcrawling_disc4 -264.591067  128.146412 -159.331292
# 1  20201013_ecadGFPnbG4_upcrawling_disc4 -259.234591  130.829734 -154.824649
# 2  20201013_ecadGFPnbG4_upcrawling_disc4 -253.878114  133.113183 -150.189445
# 3  20201013_ecadGFPnbG4_upcrawling_disc4 -248.521637  135.020409 -145.430451
# 4  20201013_ecadGFPnbG4_upcrawling_disc4 -243.165160  136.586683 -140.551750
#
#    curvature    devstage     genotype crosssection
# 0   0.014826  upcrawling  ecadGFPnbG4    Across_DV
# 1   0.015300  upcrawling  ecadGFPnbG4    Across_DV
# 2   0.014937  upcrawling  ecadGFPnbG4    Across_DV
# 3   0.013800  upcrawling  ecadGFPnbG4    Across_DV
# 4   0.012123  upcrawling  ecadGFPnbG4    Across_DV

# %%
df_mean.head()
# Out:
#       genotype    devstage   arclength           x           y       x_sd  \
# 0  ecadGFPnbG4  upcrawling -264.591067  120.838401 -164.625000  14.882452
# 1  ecadGFPnbG4  upcrawling -259.234591  123.503871 -160.031277  14.723604
# 2  ecadGFPnbG4  upcrawling -253.878114  126.220248 -155.539820  14.239348
# 3  ecadGFPnbG4  upcrawling -248.521637  128.861762 -151.054195  13.552467
# 4  ecadGFPnbG4  upcrawling -243.165160  131.333859 -146.504709  12.762725
#
#         y_sd  curvature  curvature_sd crosssection
# 0  10.522254  -0.009545      0.021176    Across_DV
# 1  10.524001  -0.002781      0.015111    Across_DV
# 2  10.763691   0.002777      0.009829    Across_DV
# 3  11.125598   0.006861      0.005476    Across_DV
# 4  11.524151   0.009675      0.002332    Across_DV

# %%
plot_mean_shapes_w_individual_traces(df_all, df_mean, devstages=devstages, 
                              scalebar_stage='upcrawling', #default None, comment this line if no scalebar text needed
                              #scalebar_x_pos = 120, scalebar_y_pos = -450, scalebar_size = 100, #default values
                              filename = plot_folder + 'mean_shape_w_individual_trace.pdf')

# %%
plot_mean_shapes_w_error_bars(df_all, df_mean,  genotypes = ['ecadGFPnbG4'], devstages=devstages, 
                              scalebar_stage='96hAEL', #default None, comment this line if no scalebar text needed
                              #scalebar_x_pos = 120, scalebar_y_pos = -450, scalebar_size = 100, #default values
                              filename = plot_folder + 'mean_shape_w_error_bars.pdf')

# %%
df = pd.DataFrame([[4, 9]] * 3, columns=['A', 'B'])
df = pd.DataFrame({"A":[1,2,3], "B":[9,8,7]})

# %%
df
# Out:
#    A  B
# 0  1  9
# 1  2  8
# 2  3  7

# %%
df.apply(lambda row: row["A"] * row["B"], axis=1)
# Out:
# 0     9
# 1    16
# 2    21
# dtype: int64
